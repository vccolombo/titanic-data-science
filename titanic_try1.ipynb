# %%
# First submission to Kaggle
# Scored 0.78947

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import  preprocessing
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("data/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_drop_id = df.drop(['PassengerId'], axis=1)
df_drop_id.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df_drop_id['Survived'].unique()
# Out:
# array([0, 1])

# %%
df_drop_cabin = df_drop_id.drop(['Cabin'], axis=1)
df_drop_cabin.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %%
df_drop_cabin['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df_fill_embarked = df_drop_cabin
df_fill_embarked['Embarked'] = df_drop_cabin['Embarked'].fillna('S')
df_fill_embarked.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %%
df_fill_embarked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Embarked    891 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
g = sns.catplot("Pclass", "Age", "Survived", data=df_fill_embarked, kind="bar", palette="pastel")
plt.show()

# %%
df_age_null = df_fill_embarked[df_fill_embarked['Age'].isnull() == True]
df_age_not_null = df_fill_embarked[df_fill_embarked['Age'].isnull() == False]

# %%
df_age_null.head()
# Out:
#     Survived  Pclass                           Name     Sex  Age  SibSp  \
# 5          0       3               Moran, Mr. James    male  NaN      0
# 17         1       2   Williams, Mr. Charles Eugene    male  NaN      0
# 19         1       3        Masselmani, Mrs. Fatima  female  NaN      0
# 26         0       3        Emir, Mr. Farred Chehab    male  NaN      0
# 28         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
#
#     Parch  Ticket     Fare Embarked
# 5       0  330877   8.4583        Q
# 17      0  244373  13.0000        S
# 19      0    2649   7.2250        C
# 26      0    2631   7.2250        C
# 28      0  330959   7.8792        Q

# %%
df_age_not_null.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %%
df_age_not_null_grouped = df_age_not_null.groupby(['Pclass', 'Sex'])
df_age_not_null_grouped.first()
# Out:
#                Survived                                               Name  \
# Pclass Sex
# 1      female         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#        male           0                            McCarthy, Mr. Timothy J
# 2      female         1                Nasser, Mrs. Nicholas (Adele Achem)
#        male           0                               Fynney, Mr. Joseph J
# 3      female         1                             Heikkinen, Miss. Laina
#        male           0                            Braund, Mr. Owen Harris
#
#                 Age  SibSp  Parch            Ticket     Fare Embarked
# Pclass Sex
# 1      female  38.0      1      0          PC 17599  71.2833        C
#        male    54.0      0      0             17463  51.8625        S
# 2      female  14.0      1      0            237736  30.0708        C
#        male    35.0      0      0            239865  26.0000        S
# 3      female  26.0      0      0  STON/O2. 3101282   7.9250        S
#        male    22.0      1      0         A/5 21171   7.2500        S

# %%
age_mean = df_age_not_null_grouped['Age'].mean().to_dict()
age_mean
# Out:
# {(1, 'female'): 34.61176470588235,
#  (1, 'male'): 41.28138613861386,
#  (2, 'female'): 28.722972972972972,
#  (2, 'male'): 30.74070707070707,
#  (3, 'female'): 21.75,
#  (3, 'male'): 26.507588932806325}

# %%
df_age_null.loc[::, 'Age'] = df_age_null.apply(lambda x: age_mean[(x['Pclass'], x['Sex'])], axis=1)
df_age_null.tail(10)
# Out:
# /home/vccolombo/Programing/titanic/.venv/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      Survived  Pclass                                          Name     Sex  \
# 832         0       3                                Saad, Mr. Amin    male
# 837         0       3                           Sirota, Mr. Maurice    male
# 839         1       1                          Marechal, Mr. Pierre    male
# 846         0       3                      Sage, Mr. Douglas Bullen    male
# 849         1       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female
# 859         0       3                              Razi, Mr. Raihed    male
# 863         0       3             Sage, Miss. Dorothy Edith "Dolly"  female
# 868         0       3                   van Melkebeke, Mr. Philemon    male
# 878         0       3                            Laleff, Mr. Kristo    male
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
#
#            Age  SibSp  Parch      Ticket     Fare Embarked
# 832  26.507589      0      0        2671   7.2292        C
# 837  26.507589      0      0      392092   8.0500        S
# 839  41.281386      0      0       11774  29.7000        C
# 846  26.507589      8      2    CA. 2343  69.5500        S
# 849  34.611765      1      0       17453  89.1042        C
# 859  26.507589      0      0        2629   7.2292        C
# 863  21.750000      8      2    CA. 2343  69.5500        S
# 868  26.507589      0      0      345777   9.5000        S
# 878  26.507589      0      0      349217   7.8958        S
# 888  21.750000      1      2  W./C. 6607  23.4500        S

# %%
df_age_concat = pd.concat([df_age_null, df_age_not_null])
df_age_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 5 to 890
# Data columns (total 10 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Embarked    891 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 76.6+ KB

# %%
df_age_concat.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df_sex = df_age_concat
df_sex.Sex = df_age_concat.Sex.apply(lambda x: 1 if x == 'male' else 0)
df_sex.head()
# Out:
#     Survived  Pclass                           Name  Sex        Age  SibSp  \
# 5          0       3               Moran, Mr. James    1  26.507589      0
# 17         1       2   Williams, Mr. Charles Eugene    1  30.740707      0
# 19         1       3        Masselmani, Mrs. Fatima    0  21.750000      0
# 26         0       3        Emir, Mr. Farred Chehab    1  26.507589      0
# 28         1       3  O'Dwyer, Miss. Ellen "Nellie"    0  21.750000      0
#
#     Parch  Ticket     Fare Embarked
# 5       0  330877   8.4583        Q
# 17      0  244373  13.0000        S
# 19      0    2649   7.2250        C
# 26      0    2631   7.2250        C
# 28      0  330959   7.8792        Q

# %%
df_sex.Name.unique()
# Out:
# array(['Moran, Mr. James', 'Williams, Mr. Charles Eugene',
#        'Masselmani, Mrs. Fatima', 'Emir, Mr. Farred Chehab',
#        'O\'Dwyer, Miss. Ellen "Nellie"', 'Todoroff, Mr. Lalio',
#        'Spencer, Mrs. William Augustus (Marie Eugenie)',
#        'Glynn, Miss. Mary Agatha', 'Mamee, Mr. Hanna',
#        'Kraeff, Mr. Theodor', 'Rogers, Mr. William John',
#        'Lennon, Mr. Denis', "O'Driscoll, Miss. Bridget",
#        'Samaan, Mr. Youssef', 'Woolner, Mr. Hugh',
#        'Stewart, Mr. Albert A', 'Moubarek, Master. Gerios',
#        'Staneff, Mr. Ivan', 'Moutal, Mr. Rahamin Haim',
#        'McDermott, Miss. Brigdet Delia', 'Slocovski, Mr. Selman Francis',
#        'Shorney, Mr. Charles Joseph', 'Petroff, Mr. Pastcho ("Pentcho")',
#        'Moss, Mr. Albert Johan', 'Moran, Miss. Bertha',
#        'Moore, Mr. Leonard Charles', 'McMahon, Mr. Martin',
#        'Peter, Miss. Anna', 'Boulos, Mrs. Joseph (Sultana)',
#        'Olsen, Mr. Ole Martin', 'Smiljanic, Mr. Mile',
#        'Sage, Master. Thomas Henry',
#        'Chibnall, Mrs. (Edith Martha Bowerman)', 'Baumann, Mr. John D',
#        'Lefebre, Master. Henry Forbes', 'Sage, Miss. Constance Gladys',
#        'Pernot, Mr. Rene', 'Rood, Mr. Hugh Roscoe',
#        'O\'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)',
#        'Mernagh, Mr. Robert', 'Madigan, Miss. Margaret "Maggie"',
#        'Sage, Mr. Frederick', 'Kiernan, Mr. Philip',
#        'Nenkoff, Mr. Christo', 'Lefebre, Miss. Mathilde',
#        'Harknett, Miss. Alice Phoebe', 'Zabour, Miss. Thamine',
#        'Murphy, Miss. Katherine "Kate"', 'Reed, Mr. James George',
#        'Thorne, Mrs. Gertrude Maybelle', 'Smith, Mr. Thomas',
#        'Henry, Miss. Delia', 'Cairns, Mr. Alexander',
#        'Healy, Miss. Hanora "Nora"', 'Parkes, Mr. Francis "Frank"',
#        'Smith, Mr. Richard William', 'Lewy, Mr. Ervin G',
#        'Saalfeld, Mr. Adolphe',
#        'Kelly, Miss. Anna Katherine "Annie Kate"', 'McCoy, Mr. Bernard',
#        'Keane, Miss. Nora A', 'Williams, Mr. Howard Hugh "Harry"',
#        'Fleming, Miss. Margaret', 'Sage, Mr. George John Jr',
#        'McCoy, Miss. Agnes',
#        'Frauenthal, Mrs. Henry William (Clara Heinsheimer)',
#        'Denkoff, Mr. Mitto', 'Davison, Mrs. Thomas Henry (Mary E Finck)',
#        'Williams-Lambert, Mr. Fletcher Fellows', 'Yousif, Mr. Wazli',
#        'McGovern, Miss. Mary', 'Mockler, Miss. Helen Mary "Ellie"',
#        "O'Brien, Mr. Thomas", 'Moussa, Mrs. (Mantoura Boulos)',
#        'Jermyn, Miss. Annie', 'Meyer, Mrs. Edgar Joseph (Leila Saks)',
#        'Plotcharsky, Mr. Vasil', 'Sadlier, Mr. Matthew',
#        'Lefebre, Miss. Ida', 'Sdycoff, Mr. Todor', 'Hart, Mr. Henry',
#        'Cunningham, Mr. Alfred Fleming',
#        'Meek, Mrs. Thomas (Annie Louise Rowley)',
#        'Gheorgheff, Mr. Stanio', 'Wiseman, Mr. Phillippe',
#        'Flynn, Mr. James',
#        'Thorneycroft, Mrs. Percival (Florence Kate White)',
#        'Johannesen-Bratthammer, Mr. Bernt',
#        'Hagland, Mr. Ingvald Olai Olsen', 'Peduzzi, Mr. Joseph',
#        'Kenyon, Mrs. Frederick R (Marion)', "O'Connor, Mr. Maurice",
#        'Maisner, Mr. Simon', 'Campbell, Mr. William',
#        'Scanlan, Mr. James', 'Keefe, Mr. Arthur',
#        'Clifford, Mr. George Quincy', 'Frost, Mr. Anthony Wood "Archie"',
#        'Lefebre, Miss. Jeannie', 'Hagland, Mr. Konrad Mathias Reiersen',
#        'Yousseff, Mr. Gerious', 'Shellard, Mr. Frederick William',
#        "O'Sullivan, Miss. Bridget Mary",
#        'Bradley, Mr. George ("George Arthur Brayton")',
#        'Webber, Mr. James', 'Ryan, Mr. Patrick', 'Lahoud, Mr. Sarkis',
#        'Kassem, Mr. Fared', 'Farthing, Mr. John', 'Toufik, Mr. Nakli',
#        'Peter, Mrs. Catherine (Catherine Rizk)',
#        'Risien, Mr. Samuel Beard', 'Padro y Manent, Mr. Julian',
#        "O'Brien, Mr. Timothy", 'Robbins, Mr. Victor',
#        'Morrow, Mr. Thomas Rowan', 'Simmons, Mr. John',
#        'Meanwell, Miss. (Marion Ogden)', 'Doharr, Mr. Tannous',
#        'Kelly, Miss. Mary', 'Caram, Mrs. Joseph (Maria Elias)',
#        'Paulner, Mr. Uscher', 'Murdlin, Mr. Joseph', 'Bourke, Miss. Mary',
#        'Leitch, Miss. Jessie Wills', 'Boulos, Mr. Hanna',
#        'Slabenoff, Mr. Petco', 'Harrington, Mr. Charles H',
#        'Jardin, Mr. Jose Neto', 'Murphy, Miss. Margaret Jane',
#        'Horgan, Mr. John', "O'Connell, Mr. Patrick D",
#        'Parr, Mr. William Henry Marsh', 'Thorneycroft, Mr. Percival',
#        'Foo, Mr. Choong', 'Willey, Mr. Edward', 'Mitkoff, Mr. Mito',
#        'O\'Leary, Miss. Hanora "Norah"', 'Radeff, Mr. Alexander',
#        'Rommetvedt, Mr. Knud Paust',
#        'Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)',
#        'Watson, Mr. Ennis Hastings', 'Peters, Miss. Katie',
#        'Lam, Mr. Ali', 'Mullens, Miss. Katherine "Katie"',
#        'Moubarek, Master. Halim Gonios ("William George")',
#        'Klaber, Mr. Herman', 'McEvoy, Mr. Michael',
#        'Mannion, Miss. Margareth', 'Knight, Mr. Robert J',
#        'Ivanoff, Mr. Kanio', 'Nankoff, Mr. Minko',
#        'Hawksford, Mr. Walter James', 'Garfirth, Mr. John',
#        'Brewe, Dr. Arthur Jackson', 'Moran, Mr. Daniel J',
#        'Elias, Mr. Dibo', 'Tobin, Mr. Roger', 'Kilgannon, Mr. Thomas J',
#        'Johnston, Mr. Andrew G', 'Keane, Mr. Andrew "Andy"',
#        'Sage, Miss. Stella Anna', 'Hoyt, Mr. William Fisher',
#        'Fry, Mr. Richard', 'Flynn, Mr. John', 'Lam, Mr. Len',
#        'McCormack, Mr. Thomas Joseph', 'Saad, Mr. Amin',
#        'Sirota, Mr. Maurice', 'Marechal, Mr. Pierre',
#        'Sage, Mr. Douglas Bullen',
#        'Goldenberg, Mrs. Samuel L (Edwiga Grabowska)', 'Razi, Mr. Raihed',
#        'Sage, Miss. Dorothy Edith "Dolly"', 'van Melkebeke, Mr. Philemon',
#        'Laleff, Mr. Kristo', 'Johnston, Miss. Catherine Helen "Carrie"',
#        'Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'McCarthy, Mr. Timothy J',
#        'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Fynney, Mr. Joseph J', 'Beesley, Mr. Lawrence',
#        'McGowan, Miss. Anna "Annie"', 'Sloper, Mr. William Thompson',
#        'Palsson, Miss. Torborg Danira',
#        'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#        'Fortune, Mr. Charles Alexander', 'Uruchurtu, Don. Manuel E',
#        'Wheadon, Mr. Edward H', 'Meyer, Mr. Edgar Joseph',
#        'Holverson, Mr. Alexander Oskar', 'Cann, Mr. Ernest Charles',
#        'Vander Planke, Miss. Augusta Maria',
#        'Nicola-Yarred, Miss. Jamila',
#        'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#        'Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)',
#        'Laroche, Miss. Simonne Marie Anne Andree',
#        'Devaney, Miss. Margaret Delia',
#        'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#        'Panula, Master. Juha Niilo', 'Nosworthy, Mr. Richard Cater',
#        'Harper, Mrs. Henry Sleeper (Myna Haxtun)',
#        'Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)',
#        'Ostby, Mr. Engelhart Cornelius', 'Rugg, Miss. Emily',
#        'Novel, Mr. Mansouer', 'West, Miss. Constance Mirium',
#        'Goodwin, Master. William Frederick', 'Sirayanian, Mr. Orsen',
#        'Icard, Miss. Amelie', 'Harris, Mr. Henry Birkhardt',
#        'Skoog, Master. Harald', 'Nye, Mrs. (Elizabeth Ramell)',
#        'Crease, Mr. Ernest James', 'Andersson, Miss. Erna Alexandra',
#        'Kink, Mr. Vincenz', 'Jenkin, Mr. Stephen Curnow',
#        'Goodwin, Miss. Lillian Amy', 'Hood, Mr. Ambrose Jr',
#        'Chronopoulos, Mr. Apostolos', 'Bing, Mr. Lee',
#        'Moen, Mr. Sigurd Hansen', 'Caldwell, Master. Alden Gates',
#        'Dowdell, Miss. Elizabeth', 'Waelens, Mr. Achille',
#        'Sheerlinck, Mr. Jan Baptist', 'Carrau, Mr. Francisco M',
#        'Ilett, Miss. Bertha',
#        'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#        'Ford, Mr. William Neal', 'Fortune, Miss. Mabel Helen',
#        'Celotti, Mr. Francesco', 'Christmann, Mr. Emil',
#        'Andreasson, Mr. Paul Edvin', 'Chaffee, Mr. Herbert Fuller',
#        'Dean, Mr. Bertram Frank', 'Coxon, Mr. Daniel',
#        'Goldschmidt, Mr. George B', 'Greenfield, Mr. William Bertram',
#        'Doling, Mrs. John T (Ada Julia Bone)', 'Kantor, Mr. Sinai',
#        'Petranec, Miss. Matilda', 'White, Mr. Richard Frasar',
#        'Johansson, Mr. Gustaf Joel', 'Gustafsson, Mr. Anders Vilhelm',
#        'Mionoff, Mr. Stoytcho', 'Salkjelsvik, Miss. Anna Kristine',
#        'Rekic, Mr. Tido', 'Porter, Mr. Walter Chamberlain',
#        'Zabour, Miss. Hileni', 'Barton, Mr. David John',
#        'Jussila, Miss. Katriina', 'Attalah, Miss. Malake',
#        'Pekoniemi, Mr. Edvard', 'Connors, Mr. Patrick',
#        'Turpin, Mr. William John Robert', 'Baxter, Mr. Quigg Edmond',
#        'Andersson, Miss. Ellis Anna Maria', 'Hickman, Mr. Stanley George',
#        'Nasser, Mr. Nicholas', 'Webber, Miss. Susan',
#        'White, Mr. Percival Wayland', 'Nicola-Yarred, Master. Elias',
#        'Madsen, Mr. Fridtjof Arne', 'Ekstrom, Mr. Johan',
#        'Drazenoic, Mr. Jozef', 'Coelho, Mr. Domingos Fernandeo',
#        'Robins, Mrs. Alexander A (Grace Charity Laury)',
#        'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#        'Sobey, Mr. Samuel James Hayden', 'Richard, Mr. Emile',
#        'Newsom, Miss. Helen Monypeny', 'Futrelle, Mr. Jacques Heath',
#        'Osen, Mr. Olaf Elon', 'Giglio, Mr. Victor',
#        'Nysten, Miss. Anna Sofia',
#        'Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)',
#        'Burke, Mr. Jeremiah', 'Andrew, Mr. Edgardo Samuel',
#        'Nicholls, Mr. Joseph Charles',
#        'Andersson, Mr. August Edvard ("Wennerstrom")',
#        'Ford, Miss. Robina Maggie "Ruby"',
#        'Navratil, Mr. Michel ("Louis M Hoffman")',
#        'Byles, Rev. Thomas Roussel Davids', 'Bateman, Rev. Robert James',
#        'Pears, Mrs. Thomas (Edith Wearne)', 'Meo, Mr. Alfonzo',
#        'van Billiard, Mr. Austin Blyler', 'Williams, Mr. Charles Duane',
#        'Gilnagh, Miss. Katherine "Katie"', 'Corn, Mr. Harry',
#        'Cribb, Mr. John Hatfield',
#        'Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)',
#        'Bengtsson, Mr. John Viktor', 'Calic, Mr. Jovo',
#        'Panula, Master. Eino Viljami',
#        'Goldsmith, Master. Frank John William "Frankie"',
#        'Skoog, Mrs. William (Anna Bernhardina Karlsson)', 'Ling, Mr. Lee',
#        'Van der hoef, Mr. Wyckoff', 'Rice, Master. Arthur',
#        'Johnson, Miss. Eleanor Ileen', 'Sivola, Mr. Antti Wilhelm',
#        'Smith, Mr. James Clinch', 'Klasen, Mr. Klas Albin',
#        'Isham, Miss. Ann Elizabeth', 'Hale, Mr. Reginald',
#        'Leonard, Mr. Lionel', 'Asplund, Master. Clarence Gustaf Hugo',
#        'Becker, Master. Richard F', 'Kink-Heilmann, Miss. Luise Gretchen',
#        'Romaine, Mr. Charles Hallace ("Mr C Rolmane")',
#        'Bourke, Mr. John', 'Turcin, Mr. Stjepan', 'Pinsky, Mrs. (Rosa)',
#        'Carbines, Mr. William',
#        'Andersen-Jensen, Miss. Carla Christine Nielsine',
#        'Navratil, Master. Michel M',
#        'Brown, Mrs. James Joseph (Margaret Tobin)',
#        'Lurette, Miss. Elise', 'Olsen, Mr. Karl Siegwart Andreas',
#        'Yrois, Miss. Henriette ("Mrs Harbeck")',
#        'Vande Walle, Mr. Nestor Cyriel', 'Johanson, Mr. Jakob Alfred',
#        'Youseff, Mr. Gerious', 'Cohen, Mr. Gurshon "Gus"',
#        'Strom, Miss. Telma Matilda', 'Backstrom, Mr. Karl Alfred',
#        'Albimona, Mr. Nassef Cassem', 'Carr, Miss. Helen "Ellen"',
#        'Blank, Mr. Henry', 'Ali, Mr. Ahmed', 'Cameron, Miss. Clear Annie',
#        'Perkin, Mr. John Henry', 'Givard, Mr. Hans Kristensen',
#        'Newell, Miss. Madeleine', 'Honkanen, Miss. Eliina',
#        'Jacobsohn, Mr. Sidney Samuel', 'Bazzani, Miss. Albina',
#        'Harris, Mr. Walter', 'Sunderland, Mr. Victor Francis',
#        'Bracken, Mr. James H', 'Green, Mr. George Henry',
#        'Hoyt, Mr. Frederick Maxfield', 'Berglund, Mr. Karl Ivar Sven',
#        'Mellors, Mr. William John', 'Lovell, Mr. John Hall ("Henry")',
#        'Fahlstrom, Mr. Arne Jonas',
#        'Harris, Mrs. Henry Birkhardt (Irene Wallach)',
#        'Larsson, Mr. Bengt Edvin', 'Sjostedt, Mr. Ernst Adolf',
#        'Asplund, Miss. Lillian Gertrud',
#        'Leyson, Mr. Robert William Norman', 'Hold, Mr. Stephen',
#        'Collyer, Miss. Marjorie "Lottie"',
#        'Pengelly, Mr. Frederick William', 'Hunt, Mr. George Henry',
#        'Coleridge, Mr. Reginald Charles', 'Maenpaa, Mr. Matti Alexanteri',
#        'Attalah, Mr. Sleiman', 'Minahan, Dr. William Edward',
#        'Lindahl, Miss. Agda Thorilda Viktoria',
#        'Hamalainen, Mrs. William (Anna)', 'Beckwith, Mr. Richard Leonard',
#        'Carter, Rev. Ernest Courtenay',
#        'Strom, Mrs. Wilhelm (Elna Matilda Persson)',
#        'Stead, Mr. William Thomas', 'Lobb, Mr. William Arthur',
#        'Rosblom, Mrs. Viktor (Helena Wilhelmina)',
#        'Touma, Mrs. Darwis (Hanne Youssef Razi)', 'Cherry, Miss. Gladys',
#        'Ward, Miss. Anna', 'Parrish, Mrs. (Lutie Davis)',
#        'Asplund, Master. Edvin Rojj Felix', 'Taussig, Mr. Emil',
#        'Harrison, Mr. William', 'Reeves, Mr. David',
#        'Panula, Mr. Ernesti Arvid', 'Persson, Mr. Ernst Ulrik',
#        'Graham, Mrs. William Thompson (Edith Junkins)',
#        'Bissette, Miss. Amelia', 'Tornquist, Mr. William Henry',
#        'Mellinger, Mrs. (Elizabeth Anne Maidment)',
#        'Natsch, Mr. Charles H', 'Andrews, Miss. Kornelia Theodosia',
#        'Lindblom, Miss. Augusta Charlotta', 'Rice, Master. Eric',
#        'Abbott, Mrs. Stanton (Rosa Hunt)', 'Duane, Mr. Frank',
#        'Olsson, Mr. Nils Johan Goransson', 'de Pelsmaeker, Mr. Alfons',
#        'Dorking, Mr. Edward Arthur', 'Stankovic, Mr. Ivan',
#        'de Mulder, Mr. Theodore', 'Naidenoff, Mr. Penko',
#        'Hosono, Mr. Masabumi', 'Connolly, Miss. Kate',
#        'Barber, Miss. Ellen "Nellie"',
#        'Bishop, Mrs. Dickinson H (Helen Walton)',
#        'Levy, Mr. Rene Jacques', 'Haas, Miss. Aloisia',
#        'Mineff, Mr. Ivan', 'Hanna, Mr. Mansour',
#        'Allison, Miss. Helen Loraine',
#        'Baxter, Mrs. James (Helene DeLaudeniere Chaput)',
#        'Johnson, Mr. William Cahoone Jr',
#        'Allison, Master. Hudson Trevor',
#        'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)',
#        'Abelson, Mr. Samuel', 'Francatelli, Miss. Laura Mabel',
#        'Hays, Miss. Margaret Bechstein', 'Ryerson, Miss. Emily Borie',
#        'Lahtinen, Mrs. William (Anna Sylfven)', 'Hendekovic, Mr. Ignjac',
#        'Hart, Mr. Benjamin', 'Nilsson, Miss. Helmina Josefina',
#        'Kantor, Mrs. Sinai (Miriam Sternin)', 'Moraweck, Dr. Ernest',
#        'Wick, Miss. Mary Natalie',
#        'Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)',
#        'Dennis, Mr. Samuel', 'Danoff, Mr. Yoto',
#        'Slayter, Miss. Hilda Mary',
#        'Caldwell, Mrs. Albert Francis (Sylvia Mae Harbaugh)',
#        'Young, Miss. Marie Grice', 'Nysveen, Mr. Johan Hansen',
#        'Ball, Mrs. (Ada E Hall)',
#        'Goldsmith, Mrs. Frank John (Emily Alice Brown)',
#        'Hippach, Miss. Jean Gertrude', 'Partner, Mr. Austen',
#        'Graham, Mr. George Edward', 'Vander Planke, Mr. Leo Edmondus',
#        'Pears, Mr. Thomas Clinton', 'Burns, Miss. Elizabeth Margaret',
#        'Dahl, Mr. Karl Edwart', 'Blackwell, Mr. Stephen Weart',
#        'Navratil, Master. Edmond Roger', 'Fortune, Miss. Alice Elizabeth',
#        'Collander, Mr. Erik Gustaf',
#        'Sedgwick, Mr. Charles Frederick Waddington',
#        'Fox, Mr. Stanley Hubert', 'Brown, Miss. Amelia "Mildred"',
#        'Smith, Miss. Marion Elsie',
#        'Coutts, Master. William Loch "William"', 'Dimic, Mr. Jovan',
#        'Odahl, Mr. Nils Martin', 'Elias, Mr. Tannous',
#        'Arnold-Franchi, Mr. Josef', 'Vanden Steen, Mr. Leo Peter',
#        'Bowerman, Miss. Elsie Edith', 'Funk, Miss. Annie Clemmer',
#        'Skoog, Mr. Wilhelm', 'del Carlo, Mr. Sebastiano',
#        'Barbara, Mrs. (Catherine David)', 'Asim, Mr. Adola',
#        'Adahl, Mr. Mauritz Nils Martin',
#        'Warren, Mrs. Frank Manley (Anna Sophia Atkinson)',
#        'Aubart, Mme. Leontine Pauline', 'Harder, Mr. George Achilles',
#        'Wiklund, Mr. Jakob Alfred', 'Beavan, Mr. William Thomas',
#        'Ringhini, Mr. Sante', 'Palsson, Miss. Stina Viola',
#        'Landergren, Miss. Aurora Adelia', 'Widener, Mr. Harry Elkins',
#        'Betros, Mr. Tannous', 'Gustafsson, Mr. Karl Gideon',
#        'Bidois, Miss. Rosalie', 'Nakid, Miss. Maria ("Mary")',
#        'Tikkanen, Mr. Juho',
#        'Holverson, Mrs. Alexander Oskar (Mary Aline Towner)',
#        'Davies, Mr. Charles Henry', 'Goodwin, Master. Sidney Leonard',
#        'Buss, Miss. Kate', 'Lehmann, Miss. Bertha',
#        'Carter, Mr. William Ernest', 'Jansson, Mr. Carl Olof',
#        'Gustafsson, Mr. Johan Birger', 'Newell, Miss. Marjorie',
#        'Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)',
#        'Johansson, Mr. Erik', 'Olsson, Miss. Elina',
#        'McKane, Mr. Peter David', 'Pain, Dr. Alfred',
#        'Trout, Mrs. William H (Jessie L)', 'Niskanen, Mr. Juha',
#        'Adams, Mr. John', 'Jussila, Miss. Mari Aina',
#        'Hakkarainen, Mr. Pekka Pietari', 'Oreskovic, Miss. Marija',
#        'Gale, Mr. Shadrach', 'Widegren, Mr. Carl/Charles Peter',
#        'Richards, Master. William Rowe',
#        'Birkeland, Mr. Hans Martin Monsen', 'Minahan, Miss. Daisy E',
#        'Sundman, Mr. Johan Julian',
#        'Drew, Mrs. James Vivian (Lulu Thorne Christian)',
#        'Silven, Miss. Lyyli Karoliina', 'Matthews, Mr. William John',
#        'Van Impe, Miss. Catharina', 'Charters, Mr. David',
#        'Zimmerman, Mr. Leo',
#        'Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria Brogren)',
#        'Rosblom, Mr. Viktor Richard',
#        'Clarke, Mrs. Charles V (Ada Maria Winfield)',
#        'Phillips, Miss. Kate Florence ("Mrs Kate Louise Phillips Marshall")',
#        'Pickard, Mr. Berk (Berk Trembisky)',
#        'Bjornstrom-Steffansson, Mr. Mauritz Hakan',
#        'Louch, Mrs. Charles Alexander (Alice Adelaide Slow)',
#        'Kallio, Mr. Nikolai Erland', 'Silvey, Mr. William Baird',
#        'Carter, Miss. Lucile Polk',
#        'Ford, Miss. Doolina Margaret "Daisy"',
#        'Richards, Mrs. Sidney (Emily Hocking)', 'Fortune, Mr. Mark',
#        'Kvillner, Mr. Johan Henrik Johannesson',
#        'Hart, Mrs. Benjamin (Esther Ada Bloomfield)', 'Hampe, Mr. Leon',
#        'Petterson, Mr. Johan Emil', 'Reynaldo, Ms. Encarnacion',
#        'Dodge, Master. Washington', 'Mellinger, Miss. Madeleine Violet',
#        'Seward, Mr. Frederic Kimber', 'Baclini, Miss. Marie Catherine',
#        'Peuchen, Major. Arthur Godfrey', 'West, Mr. Edwy Arthur',
#        'Foreman, Mr. Benjamin Laventall', 'Goldenberg, Mr. Samuel L',
#        'Jalsevac, Mr. Ivan', 'Millet, Mr. Francis Davis',
#        'Toomey, Miss. Ellen', 'Anderson, Mr. Harry',
#        'Morley, Mr. William', 'Gee, Mr. Arthur H',
#        'Milling, Mr. Jacob Christian', 'Goncalves, Mr. Manuel Estanslas',
#        'Smart, Mr. John Montgomery', 'Baclini, Miss. Helene Barbara',
#        'Cacic, Mr. Luka', 'West, Mrs. Edwy Arthur (Ada Mary Worth)',
#        'Jerwan, Mrs. Amin S (Marie Marthe Thuillard)',
#        'Strandberg, Miss. Ida Sofia', 'Renouf, Mr. Peter Henry',
#        'Braund, Mr. Lewis Richard', 'Karlsson, Mr. Nils August',
#        'Hirvonen, Miss. Hildur E', 'Goodwin, Master. Harold Victor',
#        'Rouse, Mr. Richard Henry', 'Turkula, Mrs. (Hedwig)',
#        'Bishop, Mr. Dickinson H',
#        'Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)',
#        'Kent, Mr. Edward Austin', 'Somerton, Mr. Francis William',
#        'Coutts, Master. Eden Leslie "Neville"', 'Windelov, Mr. Einar',
#        'Molson, Mr. Harry Markland', 'Artagaveytia, Mr. Ramon',
#        'Stanley, Mr. Edward Roland', 'Eustis, Miss. Elizabeth Mussey',
#        'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#        'Svensson, Mr. Olof', 'Calic, Mr. Petar', 'Canavan, Miss. Mary',
#        'Laitinen, Miss. Kristina Sofia', 'Maioni, Miss. Roberta',
#        'Penasco y Castellana, Mr. Victor de Satode',
#        'Quick, Mrs. Frederick Charles (Jane Richards)',
#        'Olsen, Mr. Henry Margido', 'Lang, Mr. Fang',
#        'Daly, Mr. Eugene Patrick', 'McGough, Mr. James Robert',
#        'Rothschild, Mrs. Martin (Elizabeth L. Barrett)',
#        'Coleff, Mr. Satio', 'Walker, Mr. William Anderson',
#        'Lemore, Mrs. (Amelia Milley)',
#        'Angle, Mrs. William A (Florence "Mary" Agnes Hughes)',
#        'Pavlovic, Mr. Stefo', 'Perreault, Miss. Anne', 'Vovk, Mr. Janko',
#        'Hippach, Mrs. Louis Albert (Ida Sophia Fischer)',
#        'Farrell, Mr. James', 'Ridsdale, Miss. Lucy',
#        'Salonen, Mr. Johan Werner', 'Hocking, Mr. Richard George',
#        'Quick, Miss. Phyllis May', 'Elias, Mr. Joseph Jr',
#        'Cacic, Miss. Marija', 'Hart, Miss. Eva Miriam',
#        'Butt, Major. Archibald Willingham', 'LeRoy, Miss. Bertha',
#        'Frolicher, Miss. Hedwig Margaritha', 'Crosby, Miss. Harriet R',
#        'Andersson, Miss. Ingeborg Constanzia',
#        'Andersson, Miss. Sigrid Elisabeth', 'Beane, Mr. Edward',
#        'Douglas, Mr. Walter Donald', 'Nicholson, Mr. Arthur Ernest',
#        'Beane, Mrs. Edward (Ethel Clarke)', 'Goldsmith, Mr. Frank John',
#        'Davies, Master. John Morgan Jr', 'Thayer, Mr. John Borland Jr',
#        'Sharp, Mr. Percival James R', 'Leeni, Mr. Fahim ("Philip Zenni")',
#        'Ohman, Miss. Velin', 'Wright, Mr. George',
#        'Duff Gordon, Lady. (Lucille Christiana Sutherland) ("Mrs Morgan")',
#        'Taussig, Mrs. Emil (Tillie Mandelbaum)',
#        'de Messemaeker, Mrs. Guillaume Joseph (Emma)',
#        'Sivic, Mr. Husein', 'Norman, Mr. Robert Douglas',
#        'Davies, Mr. Alfred J', 'Stoytcheff, Mr. Ilia',
#        'Palsson, Mrs. Nils (Alma Cornelia Berglund)', 'Jonsson, Mr. Carl',
#        'Harris, Mr. George',
#        'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#        'Flynn, Mr. John Irwin ("Irving")', 'Rush, Mr. Alfred George John',
#        'Patchett, Mr. George', 'Garside, Miss. Ethel',
#        'Silvey, Mrs. William Baird (Alice Munger)', 'Jussila, Mr. Eiriik',
#        'Christy, Miss. Julie Rachel',
#        'Thayer, Mrs. John Borland (Marian Longstreth Morris)',
#        'Downton, Mr. William James', 'Ross, Mr. John Hugo',
#        'Taussig, Miss. Ruth', 'Jarvis, Mr. John Denzil',
#        'Frolicher-Stehli, Mr. Maxmillian', 'Gilinski, Mr. Eliezer',
#        'Rintamaki, Mr. Matti',
#        'Stephenson, Mrs. Walter Bertram (Martha Eustis)',
#        'Elsbury, Mr. William James', 'Chapman, Mr. John Henry',
#        'Van Impe, Mr. Jean Baptiste', 'Johnson, Mr. Alfred',
#        'Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")',
#        'Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)',
#        'Torber, Mr. Ernst William', 'Homer, Mr. Harry ("Mr E Haven")',
#        'Lindell, Mr. Edvard Bengtsson', 'Karaic, Mr. Milan',
#        'Daniel, Mr. Robert Williams',
#        'Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)',
#        'Shutes, Miss. Elizabeth W',
#        'Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)',
#        'Brocklebank, Mr. William Alfred', 'Herman, Miss. Alice',
#        'Danbom, Mr. Ernst Gilbert',
#        'Lobb, Mrs. William Arthur (Cordelia K Stanlick)',
#        'Becker, Miss. Marion Louise', 'Gavey, Mr. Lawrence',
#        'Yasbeck, Mr. Antoni', 'Kimball, Mr. Edwin Nelson Jr',
#        'Nakid, Mr. Sahid', 'Hansen, Mr. Henry Damsgaard',
#        'Bowen, Mr. David John "Dai"', 'Sutton, Mr. Frederick',
#        'Kirkland, Rev. Charles Leonard', 'Longley, Miss. Gretchen Fiske',
#        'Bostandyeff, Mr. Guentcho',
#        'Barkworth, Mr. Algernon Henry Wilson',
#        'Lundahl, Mr. Johan Svensson', 'Stahelin-Maeglin, Dr. Max',
#        'Skoog, Miss. Mabel', 'Davis, Miss. Mary',
#        'Leinonen, Mr. Antti Gustaf', 'Collyer, Mr. Harvey',
#        'Panula, Mrs. Juha (Maria Emilia Ojala)', 'Jensen, Mr. Hans Peder',
#        'Sagesser, Mlle. Emma', 'Skoog, Miss. Margit Elizabeth',
#        'Baclini, Miss. Eugenie', 'Harper, Mr. Henry Sleeper',
#        'Cor, Mr. Liudevit', 'Simonius-Blumer, Col. Oberst Alfons',
#        'Stanley, Miss. Amy Zillah Elsie', 'Doling, Miss. Elsie',
#        'Kalvik, Mr. Johannes Halvorsen', 'Hegarty, Miss. Hanora "Nora"',
#        'Hickman, Mr. Leonard Mark', 'Bourke, Mrs. John (Catherine)',
#        'Eitemiller, Mr. George Floyd', 'Newell, Mr. Arthur Webster',
#        'Frauenthal, Dr. Henry William', 'Badt, Mr. Mohamed',
#        'Colley, Mr. Edward Pomeroy', 'Coleff, Mr. Peju',
#        'Lindqvist, Mr. Eino William', 'Hickman, Mr. Lewis',
#        'Butler, Mr. Reginald Fenton', 'Cook, Mr. Jacob',
#        'Brown, Mrs. Thomas William Solomon (Elizabeth Catherine Ford)',
#        'Davidson, Mr. Thornton', 'Mitchell, Mr. Henry Michael',
#        'Wilhelms, Mr. Charles', 'Edvardsson, Mr. Gustaf Hjalmar',
#        'Sawyer, Mr. Frederick Charles', 'Turja, Miss. Anna Sofia',
#        'Goodwin, Mrs. Frederick (Augusta Tyler)',
#        'Cardeza, Mr. Thomas Drake Martinez', 'Hassab, Mr. Hammad',
#        'Olsvigen, Mr. Thor Anderson', 'Goodwin, Mr. Charles Edward',
#        'Brown, Mr. Thomas William Solomon',
#        'Laroche, Mr. Joseph Philippe Lemercier',
#        'Panula, Mr. Jaako Arnold', 'Dakic, Mr. Branko',
#        'Fischer, Mr. Eberhard Thelander',
#        'Madill, Miss. Georgette Alexandra', 'Dick, Mr. Albert Adrian',
#        'Karun, Miss. Manca', 'Saad, Mr. Khalil', 'Weir, Col. John',
#        'Chapman, Mr. Charles Henry', 'Kelly, Mr. James',
#        'Thayer, Mr. John Borland',
#        'Humblen, Mr. Adolf Mathias Nicolai Olsen',
#        'Astor, Mrs. John Jacob (Madeleine Talmadge Force)',
#        'Silverthorne, Mr. Spencer Victor', 'Barbara, Miss. Saiide',
#        'Gallagher, Mr. Martin', 'Hansen, Mr. Henrik Juul',
#        'Morley, Mr. Henry Samuel ("Mr Henry Marshall")',
#        'Kelly, Mrs. Florence "Fannie"',
#        'Calderhead, Mr. Edward Pennington', 'Cleaver, Miss. Alice',
#        'Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")',
#        'Taylor, Mr. Elmer Zebley', 'Larsson, Mr. August Viktor',
#        'Greenberg, Mr. Samuel',
#        'Soholt, Mr. Peter Andreas Lauritz Andersen',
#        'Endres, Miss. Caroline Louise',
#        'Troutt, Miss. Edwina Celia "Winnie"',
#        'Johnson, Mr. Malkolm Joackim',
#        'Harper, Miss. Annie Jessie "Nina"', 'Jensen, Mr. Svend Lauritz',
#        'Gillespie, Mr. William Henry', 'Hodges, Mr. Henry Price',
#        'Chambers, Mr. Norman Campbell', 'Oreskovic, Mr. Luka',
#        'Renouf, Mrs. Peter Henry (Lillian Jefferys)',
#        'Bryhl, Mr. Kurt Arnold Gottfrid', 'Ilmakangas, Miss. Pieta Sofia',
#        'Allen, Miss. Elisabeth Walton', 'Hassan, Mr. Houssein G N',
#        'Berriman, Mr. William John', 'Troupiansky, Mr. Moses Aaron',
#        'Williams, Mr. Leslie', 'Ford, Mrs. Edward (Margaret Ann Watson)',
#        'Lesurer, Mr. Gustave J', 'Cavendish, Mr. Tyrell William',
#        'Ryerson, Miss. Susan Parker "Suzette"', 'McNamee, Mr. Neal',
#        'Stranden, Mr. Juho', 'Crosby, Capt. Edward Gifford',
#        'Abbott, Mr. Rossmore Edward', 'Sinkkonen, Miss. Anna',
#        'Marvin, Mr. Daniel Warner', 'Connaghton, Mr. Michael',
#        'Wells, Miss. Joan', 'Moor, Master. Meier',
#        'Vande Velde, Mr. Johannes Joseph', 'Jonkoff, Mr. Lalio',
#        'Herman, Mrs. Samuel (Jane Laver)', 'Hamalainen, Master. Viljo',
#        'Carlsson, Mr. August Sigfrid', 'Bailey, Mr. Percy Andrew',
#        'Theobald, Mr. Thomas Leonard',
#        'Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)',
#        'Nirva, Mr. Iisakki Antino Aijo', 'Barah, Mr. Hanna Assi',
#        'Carter, Mrs. William Ernest (Lucile Polk)',
#        'Eklund, Mr. Hans Linus', 'Hogeboom, Mrs. John C (Anna Andrews)',
#        'Mangan, Miss. Mary', 'Gronnestad, Mr. Daniel Danielsen',
#        'Lievens, Mr. Rene Aime', 'Jensen, Mr. Niels Peder',
#        'Mack, Mrs. (Mary)', 'Hocking, Mrs. Elizabeth (Eliza Needs)',
#        'Myhrman, Mr. Pehr Fabian Oliver Malkolm',
#        'Emanuel, Miss. Virginia Ethel',
#        'Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)',
#        'Ayoub, Miss. Banoura',
#        'Dick, Mrs. Albert Adrian (Vera Gillespie)',
#        'Long, Mr. Milton Clyde', 'Ali, Mr. William',
#        'Harmer, Mr. Abraham (David Lishin)', 'Sjoblom, Miss. Anna Sofia',
#        'Rice, Master. George Hugh', 'Dean, Master. Bertram Vere',
#        'Guggenheim, Mr. Benjamin', 'Gaskell, Mr. Alfred',
#        'Dantcheff, Mr. Ristiu', 'Otter, Mr. Richard',
#        'Leader, Dr. Alice (Farnham)', 'Osman, Mrs. Mara',
#        'Ibrahim Shawah, Mr. Yousseff',
#        'Van Impe, Mrs. Jean Baptiste (Rosalie Paula Govaert)',
#        'Ponesell, Mr. Martin',
#        'Collyer, Mrs. Harvey (Charlotte Annie Tate)',
#        'Carter, Master. William Thornton II',
#        'Thomas, Master. Assad Alexander', 'Hedman, Mr. Oskar Arvid',
#        'Johansson, Mr. Karl Johan', 'Andrews, Mr. Thomas Jr',
#        'Pettersson, Miss. Ellen Natalia', 'Meyer, Mr. August',
#        'Chambers, Mrs. Norman Campbell (Bertha Griggs)',
#        'Alexander, Mr. William', 'Lester, Mr. James',
#        'Slemen, Mr. Richard James', 'Andersson, Miss. Ebba Iris Alfrida',
#        'Tomlin, Mr. Ernest Portage', 'Heininen, Miss. Wendla Maria',
#        'Mallet, Mr. Albert', 'Holm, Mr. John Fredrik Alexander',
#        'Skoog, Master. Karl Thorsten',
#        'Hays, Mrs. Charles Melville (Clara Jennings Gregg)',
#        'Lulic, Mr. Nikola', 'Reuchlin, Jonkheer. John George',
#        'Moor, Mrs. (Beila)', 'Panula, Master. Urho Abraham',
#        'Mallet, Master. Andre',
#        'Stone, Mrs. George Nelson (Martha Evelyn)',
#        'Yasbeck, Mrs. Antoni (Selini Alexander)',
#        'Richards, Master. George Sibley', 'Augustsson, Mr. Albert',
#        'Allum, Mr. Owen George', 'Compton, Miss. Sara Rebecca',
#        'Pasic, Mr. Jakob', 'Chip, Mr. Chang',
#        'Alhomaki, Mr. Ilmari Rudolf', 'Mudd, Mr. Thomas Charles',
#        'Serepeca, Miss. Augusta', 'Lemberopolous, Mr. Peter L',
#        'Culumovic, Mr. Jeso', 'Abbing, Mr. Anthony', 'Markoff, Mr. Marin',
#        'Harper, Rev. John', 'Andersson, Master. Sigvard Harald Elias',
#        'Svensson, Mr. Johan', 'Boulos, Miss. Nourelain',
#        'Lines, Miss. Mary Conover',
#        'Carter, Mrs. Ernest Courtenay (Lilian Hughes)',
#        'Aks, Mrs. Sam (Leah Rosen)',
#        'Wick, Mrs. George Dennick (Mary Hitchcock)',
#        'Daly, Mr. Peter Denis ', 'Baclini, Mrs. Solomon (Latifa Qurban)',
#        'Hansen, Mr. Claus Peter', 'Giles, Mr. Frederick Edward',
#        'Swift, Mrs. Frederick Joel (Margaret Welles Barron)',
#        'Gill, Mr. John William', 'Bystrom, Mrs. (Karolina)',
#        'Duran y More, Miss. Asuncion',
#        'Roebling, Mr. Washington Augustus II',
#        'Johnson, Master. Harold Theodor', 'Balkic, Mr. Cerin',
#        'Beckwith, Mrs. Richard Leonard (Sallie Monypeny)',
#        'Carlsson, Mr. Frans Olof', 'Vander Cruyssen, Mr. Victor',
#        'Abelson, Mrs. Samuel (Hannah Wizosky)',
#        'Najib, Miss. Adele Kiamie "Jane"',
#        'Gustafsson, Mr. Alfred Ossian', 'Petroff, Mr. Nedelio',
#        'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#        'Shelley, Mrs. William (Imanita Parrish Hall)',
#        'Markun, Mr. Johann', 'Dahlberg, Miss. Gerda Ulrika',
#        'Banfield, Mr. Frederick James', 'Sutehall, Mr. Henry Jr',
#        'Rice, Mrs. William (Margaret Norton)', 'Montvila, Rev. Juozas',
#        'Graham, Miss. Margaret Edith', 'Behr, Mr. Karl Howell',
#        'Dooley, Mr. Patrick'], dtype=object)

# %%
def get_title(name):
    for word in name.split():
        if '.' in word:
            return word

df_with_title = df_sex
df_with_title['Title'] = df_with_title['Name'].apply(get_title)
df_with_title['Title'].value_counts()
# Out:
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# Capt.          1
# Countess.      1
# Ms.            1
# Jonkheer.      1
# Don.           1
# Lady.          1
# Sir.           1
# Mme.           1
# Name: Title, dtype: int64

# %%
most_common_titles = ['Mr.', 'Miss.', 'Mrs.', 'Master.']
df_with_title['Title'] = df_with_title['Title'].apply(lambda x: x if x in most_common_titles else 'Other')
df_with_title['Title'].value_counts()
# Out:
# Mr.        517
# Miss.      182
# Mrs.       125
# Master.     40
# Other       27
# Name: Title, dtype: int64

# %%
encoder_title = preprocessing.LabelEncoder()
title = encoder_title.fit_transform(df_with_title['Title'])
encoder_title.classes_
# Out:
# array(['Master.', 'Miss.', 'Mr.', 'Mrs.', 'Other'], dtype=object)

# %%
df_with_title['Title'] = title
df_with_title.head()
# Out:
#     Survived  Pclass                           Name  Sex        Age  SibSp  \
# 5          0       3               Moran, Mr. James    1  26.507589      0
# 17         1       2   Williams, Mr. Charles Eugene    1  30.740707      0
# 19         1       3        Masselmani, Mrs. Fatima    0  21.750000      0
# 26         0       3        Emir, Mr. Farred Chehab    1  26.507589      0
# 28         1       3  O'Dwyer, Miss. Ellen "Nellie"    0  21.750000      0
#
#     Parch  Ticket     Fare Embarked  Title
# 5       0  330877   8.4583        Q      2
# 17      0  244373  13.0000        S      2
# 19      0    2649   7.2250        C      3
# 26      0    2631   7.2250        C      2
# 28      0  330959   7.8792        Q      1

# %%
df_with_title['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
encoder_embarked = preprocessing.LabelEncoder()
embarked = encoder_embarked.fit_transform(df_with_title['Embarked'])
encoder_embarked.classes_
# Out:
# array(['C', 'Q', 'S'], dtype=object)

# %%
df_changed_embarked = df_with_title
df_changed_embarked['Embarked'] = embarked
df_changed_embarked.head()
# Out:
#     Survived  Pclass                           Name  Sex        Age  SibSp  \
# 5          0       3               Moran, Mr. James    1  26.507589      0
# 17         1       2   Williams, Mr. Charles Eugene    1  30.740707      0
# 19         1       3        Masselmani, Mrs. Fatima    0  21.750000      0
# 26         0       3        Emir, Mr. Farred Chehab    1  26.507589      0
# 28         1       3  O'Dwyer, Miss. Ellen "Nellie"    0  21.750000      0
#
#     Parch  Ticket     Fare  Embarked  Title
# 5       0  330877   8.4583         1      2
# 17      0  244373  13.0000         2      2
# 19      0    2649   7.2250         0      3
# 26      0    2631   7.2250         0      2
# 28      0  330959   7.8792         1      1

# %%
df_changed_embarked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 5 to 890
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null int64
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Embarked    891 non-null int64
# Title       891 non-null int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 83.5+ KB

# %%
df_droped = df_changed_embarked.drop(['Name', 'Ticket'], axis=1)
df_droped.head()
# Out:
#     Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  Title
# 5          0       3    1  26.507589      0      0   8.4583         1      2
# 17         1       2    1  30.740707      0      0  13.0000         2      2
# 19         1       3    0  21.750000      0      0   7.2250         0      3
# 26         0       3    1  26.507589      0      0   7.2250         0      2
# 28         1       3    0  21.750000      0      0   7.8792         1      1

# %%
df_droped.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.067485 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.407015  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.112851 -0.114631 -0.245489
# Age      -0.067485 -0.407015  0.112851  1.000000 -0.251313 -0.180705
# SibSp    -0.035322  0.083081 -0.114631 -0.251313  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.180705  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.118308  0.159651  0.216225
# Embarked -0.167675  0.162098  0.108262 -0.011184  0.068230  0.039798
# Title    -0.052471 -0.195910  0.040484  0.481038 -0.213887 -0.122792
#
#               Fare  Embarked     Title
# Survived  0.257307 -0.167675 -0.052471
# Pclass   -0.549500  0.162098 -0.195910
# Sex      -0.182333  0.108262  0.040484
# Age       0.118308 -0.011184  0.481038
# SibSp     0.159651  0.068230 -0.213887
# Parch     0.216225  0.039798 -0.122792
# Fare      1.000000 -0.224719 -0.009068
# Embarked -0.224719  1.000000 -0.011509
# Title    -0.009068 -0.011509  1.000000

# %%
g = sns.barplot(x="SibSp", y="Survived", data=df_droped)
plt.show()

# %%
g = sns.barplot(x="Parch", y="Survived", data=df_droped)
plt.show()

# %%
g = sns.barplot(x="Age", y="Survived", data=df_droped)
plt.show()

# %%
g = sns.barplot(x="Age", y="Survived", data=df_droped[df_droped['Age'] < 20])
plt.show()

# %%
g = sns.barplot(x="Age", y="Survived", data=df_droped[df_droped['Age'] < 10])
plt.show()

# %%
g = sns.barplot(x="Age", y="Survived", data=df_droped[df_droped['Age'] > 40])
plt.show()

# %%
g = sns.barplot(x="Sex", y="Survived", data=df_droped)
plt.show()

# %%
def define_age_group(age):
    if age < 16:
        return 1
    return 0
    

df_age_group = df_droped
df_age_group['ageGroup'] = df_droped['Age'].apply(define_age_group)
df_age_group.head()
# Out:
#     Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  Title  \
# 5          0       3    1  26.507589      0      0   8.4583         1      2
# 17         1       2    1  30.740707      0      0  13.0000         2      2
# 19         1       3    0  21.750000      0      0   7.2250         0      3
# 26         0       3    1  26.507589      0      0   7.2250         0      2
# 28         1       3    0  21.750000      0      0   7.8792         1      1
#
#     ageGroup
# 5          0
# 17         0
# 19         0
# 26         0
# 28         0

# %%
df_is_alone = df_age_group
df_is_alone['isAlone'] = df_is_alone['SibSp'] + df_is_alone['Parch']
df_is_alone['isAlone'] = df_is_alone['isAlone'].apply(lambda x: 0 if x > 0 else 1)
df_is_alone.head(10)
# Out:
#     Survived  Pclass  Sex        Age  SibSp  Parch      Fare  Embarked  Title  \
# 5          0       3    1  26.507589      0      0    8.4583         1      2
# 17         1       2    1  30.740707      0      0   13.0000         2      2
# 19         1       3    0  21.750000      0      0    7.2250         0      3
# 26         0       3    1  26.507589      0      0    7.2250         0      2
# 28         1       3    0  21.750000      0      0    7.8792         1      1
# 29         0       3    1  26.507589      0      0    7.8958         2      2
# 31         1       1    0  34.611765      1      0  146.5208         0      3
# 32         1       3    0  21.750000      0      0    7.7500         1      1
# 36         1       3    1  26.507589      0      0    7.2292         0      2
# 42         0       3    1  26.507589      0      0    7.8958         0      2
#
#     ageGroup  isAlone
# 5          0        1
# 17         0        1
# 19         0        1
# 26         0        1
# 28         0        1
# 29         0        1
# 31         0        0
# 32         0        1
# 36         0        1
# 42         0        1

# %%
df_is_alone.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.067485 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.407015  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.112851 -0.114631 -0.245489
# Age      -0.067485 -0.407015  0.112851  1.000000 -0.251313 -0.180705
# SibSp    -0.035322  0.083081 -0.114631 -0.251313  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.180705  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.118308  0.159651  0.216225
# Embarked -0.167675  0.162098  0.108262 -0.011184  0.068230  0.039798
# Title    -0.052471 -0.195910  0.040484  0.481038 -0.213887 -0.122792
# ageGroup  0.136107  0.121920 -0.111141 -0.554127  0.352437  0.351481
# isAlone  -0.203367  0.135207  0.303646  0.183628 -0.584471 -0.583398
#
#               Fare  Embarked     Title  ageGroup   isAlone
# Survived  0.257307 -0.167675 -0.052471  0.136107 -0.203367
# Pclass   -0.549500  0.162098 -0.195910  0.121920  0.135207
# Sex      -0.182333  0.108262  0.040484 -0.111141  0.303646
# Age       0.118308 -0.011184  0.481038 -0.554127  0.183628
# SibSp     0.159651  0.068230 -0.213887  0.352437 -0.584471
# Parch     0.216225  0.039798 -0.122792  0.351481 -0.583398
# Fare      1.000000 -0.224719 -0.009068  0.003753 -0.271832
# Embarked -0.224719  1.000000 -0.011509 -0.012338  0.063532
# Title    -0.009068 -0.011509  1.000000 -0.499766  0.028812
# ageGroup  0.003753 -0.012338 -0.499766  1.000000 -0.347400
# isAlone  -0.271832  0.063532  0.028812 -0.347400  1.000000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_is_alone.drop(['Survived'], axis=1), df_is_alone['Survived'], test_size=0.2, random_state=42)

# %%
X_train.head()
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  ageGroup  \
# 193       2    1   3.0      1      1  26.0000         2      0         1
# 701       1    1  35.0      0      0  26.2875         2      2         0
# 254       3    0  41.0      0      2  20.2125         2      3         0
# 666       2    1  25.0      0      0  13.0000         2      2         0
# 799       3    0  30.0      1      1  24.1500         2      3         0
#
#      isAlone
# 193        0
# 701        1
# 254        0
# 666        1
# 799        0

# %%
parameters = {'max_depth': np.arange(1, 10, 1), 
              'min_samples_split': np.arange(2, 10, 1), 
              'min_samples_leaf': np.arange(1, 10, 1)}

tree = DecisionTreeClassifier(random_state=0).fit(X_train, y_train)
clf = GridSearchCV(tree, parameters, cv=10,scoring='balanced_accuracy')

clf.fit(X_train, y_train)

print(clf.best_score_,clf.best_params_)
print("Accuracy:",metrics.accuracy_score(y_test, clf.predict(X_test)))
# Out:
# 0.8014176489973459 {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8100558659217877
# /home/vccolombo/Programing/titanic/.venv/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
parameters = {'C':np.arange(0.1,2,0.05), 'solver':['lbfgs', 'liblinear'], 'multi_class':['auto']}

lr = LogisticRegression(random_state=0, max_iter=1000)
clf = GridSearchCV(lr, parameters, cv=10,scoring='balanced_accuracy')

clf.fit(X_train, y_train)

print(clf.best_score_,clf.best_params_)
print("Accuracy:",metrics.accuracy_score(y_test, clf.predict(X_test)))
# Out:
# 0.7884749089184678 {'C': 0.1, 'multi_class': 'auto', 'solver': 'lbfgs'}
# Accuracy: 0.8268156424581006

# %%
clf = xgb.XGBClassifier().fit(X_train, y_train)
print("Accuracy:",metrics.accuracy_score(y_test, clf.predict(X_test)))
# Out:
# Accuracy: 0.8044692737430168

# %%
##############

# %%
test = pd.read_csv("data/test.csv")
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
def get_title(name):
    for word in name.split():
        if '.' in word:
            return word

test_with_title = test
test_with_title['Title'] = test_with_title['Name'].apply(get_title)
test_with_title['Title'].value_counts()
# Out:
# Mr.        240
# Miss.       78
# Mrs.        72
# Master.     21
# Rev.         2
# Col.         2
# Dr.          1
# Dona.        1
# Ms.          1
# Name: Title, dtype: int64

# %%
most_common_titles = ['Mr.', 'Miss.', 'Mrs.', 'Master.']
test_with_title['Title'] = test_with_title['Title'].apply(lambda x: x if x in most_common_titles else 'Other')
test_with_title['Title'].value_counts()
# Out:
# Mr.        240
# Miss.       78
# Mrs.        72
# Master.     21
# Other        7
# Name: Title, dtype: int64

# %%
test_drop_cabin = test_with_title.drop(['Cabin'], axis=1)
test_drop_cabin.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked Title
# 0  34.5      0      0   330911   7.8292        Q   Mr.
# 1  47.0      1      0   363272   7.0000        S  Mrs.
# 2  62.0      0      0   240276   9.6875        Q   Mr.
# 3  27.0      0      0   315154   8.6625        S   Mr.
# 4  22.0      1      1  3101298  12.2875        S  Mrs.

# %%
test_age_null = test_drop_cabin[test_drop_cabin['Age'].isnull() == True]
test_age_not_null = test_drop_cabin[test_drop_cabin['Age'].isnull() == False]

test_age_null.loc[::, 'Age'] = test_age_null.apply(lambda x: age_mean[(x['Pclass'], x['Sex'])], axis=1)
test_age_null.tail(10)
# Out:
# /home/vccolombo/Programing/titanic/.venv/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      PassengerId  Pclass                             Name     Sex        Age  \
# 365         1257       3   Sage, Mrs. John (Annie Bullen)  female  21.750000
# 366         1258       3                Caram, Mr. Joseph    male  26.507589
# 380         1272       3            O'Connor, Mr. Patrick    male  26.507589
# 382         1274       3       Risien, Mrs. Samuel (Emma)  female  21.750000
# 384         1276       2   Wheeler, Mr. Edwin Frederick""    male  30.740707
# 408         1300       3  Riordan, Miss. Johanna Hannah""  female  21.750000
# 410         1302       3           Naughton, Miss. Hannah  female  21.750000
# 413         1305       3               Spector, Mr. Woolf    male  26.507589
# 416         1308       3              Ware, Mr. Frederick    male  26.507589
# 417         1309       3         Peter, Master. Michael J    male  26.507589
#
#      SibSp  Parch         Ticket     Fare Embarked    Title
# 365      1      9       CA. 2343  69.5500        S     Mrs.
# 366      1      0           2689  14.4583        C      Mr.
# 380      0      0         366713   7.7500        Q      Mr.
# 382      0      0         364498  14.5000        S     Mrs.
# 384      0      0  SC/PARIS 2159  12.8750        S      Mr.
# 408      0      0         334915   7.7208        Q    Miss.
# 410      0      0         365237   7.7500        Q    Miss.
# 413      0      0      A.5. 3236   8.0500        S      Mr.
# 416      0      0         359309   8.0500        S      Mr.
# 417      1      1           2668  22.3583        C  Master.

# %%
test_fix_age = pd.concat([test_age_null, test_age_not_null])
test_fix_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 10 to 415
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Embarked       418 non-null object
# Title          418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 39.2+ KB

# %%
test_fix_age.tail()
# Out:
#      PassengerId  Pclass                                             Name  \
# 409         1301       3                        Peacock, Miss. Treasteall
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Embarked  Title
# 409  female   3.0      1      1  SOTON/O.Q. 3101315   13.775        S  Miss.
# 411  female  37.0      1      0               19928   90.000        Q   Mrs.
# 412  female  28.0      0      0              347086    7.775        S  Miss.
# 414  female  39.0      0      0            PC 17758  108.900        C  Other
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.250        S    Mr.

# %%
test = test_fix_age.drop(['Name', 'Ticket'], axis=1)
test.head()
# Out:
#     PassengerId  Pclass     Sex        Age  SibSp  Parch     Fare Embarked  \
# 10          902       3    male  26.507589      0      0   7.8958        S
# 22          914       1  female  34.611765      0      0  31.6833        S
# 29          921       3    male  26.507589      2      0  21.6792        C
# 33          925       3  female  21.750000      1      2  23.4500        S
# 36          928       3  female  21.750000      0      0   8.0500        S
#
#     Title
# 10    Mr.
# 22   Mrs.
# 29    Mr.
# 33   Mrs.
# 36  Miss.

# %%
def define_age_group(age):
    if age < 16:
        return 1
    return 0
    

test_age_group = test
test_age_group['ageGroup'] = test['Age'].apply(define_age_group)
test_age_group.head()
# Out:
#     PassengerId  Pclass     Sex        Age  SibSp  Parch     Fare Embarked  \
# 10          902       3    male  26.507589      0      0   7.8958        S
# 22          914       1  female  34.611765      0      0  31.6833        S
# 29          921       3    male  26.507589      2      0  21.6792        C
# 33          925       3  female  21.750000      1      2  23.4500        S
# 36          928       3  female  21.750000      0      0   8.0500        S
#
#     Title  ageGroup
# 10    Mr.         0
# 22   Mrs.         0
# 29    Mr.         0
# 33   Mrs.         0
# 36  Miss.         0

# %%
test_is_alone = test
test_is_alone['isAlone'] = test_is_alone['SibSp'] + test_is_alone['Parch']
test_is_alone['isAlone'] = test_is_alone['isAlone'].apply(lambda x: 0 if x > 0 else 1)
test_is_alone.head(10)
# Out:
#     PassengerId  Pclass     Sex        Age  SibSp  Parch     Fare Embarked  \
# 10          902       3    male  26.507589      0      0   7.8958        S
# 22          914       1  female  34.611765      0      0  31.6833        S
# 29          921       3    male  26.507589      2      0  21.6792        C
# 33          925       3  female  21.750000      1      2  23.4500        S
# 36          928       3  female  21.750000      0      0   8.0500        S
# 39          931       3    male  26.507589      0      0  56.4958        S
# 41          933       1    male  41.281386      0      0  26.5500        S
# 47          939       3    male  26.507589      0      0   7.7500        Q
# 54          946       2    male  30.740707      0      0  15.5792        C
# 58          950       3    male  26.507589      1      0  16.1000        S
#
#     Title  ageGroup  isAlone
# 10    Mr.         0        1
# 22   Mrs.         0        1
# 29    Mr.         0        0
# 33   Mrs.         0        0
# 36  Miss.         0        1
# 39    Mr.         0        1
# 41    Mr.         0        1
# 47    Mr.         0        1
# 54    Mr.         0        1
# 58    Mr.         0        0

# %%
test = test_is_alone.sort_values(by='PassengerId')
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Title  \
# 0          892       3    male  34.5      0      0   7.8292        Q   Mr.
# 1          893       3  female  47.0      1      0   7.0000        S  Mrs.
# 2          894       2    male  62.0      0      0   9.6875        Q   Mr.
# 3          895       3    male  27.0      0      0   8.6625        S   Mr.
# 4          896       3  female  22.0      1      1  12.2875        S  Mrs.
#
#    ageGroup  isAlone
# 0         0        1
# 1         0        0
# 2         0        1
# 3         0        1
# 4         0        0

# %%
encoder_embarked = preprocessing.LabelEncoder()
embarked = encoder_embarked.fit_transform(test['Embarked'])
encoder_embarked.classes_
# Out:
# array(['C', 'Q', 'S'], dtype=object)

# %%
test['Embarked'] = embarked
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare  Embarked Title  \
# 0          892       3    male  34.5      0      0   7.8292         1   Mr.
# 1          893       3  female  47.0      1      0   7.0000         2  Mrs.
# 2          894       2    male  62.0      0      0   9.6875         1   Mr.
# 3          895       3    male  27.0      0      0   8.6625         2   Mr.
# 4          896       3  female  22.0      1      1  12.2875         2  Mrs.
#
#    ageGroup  isAlone
# 0         0        1
# 1         0        0
# 2         0        1
# 3         0        1
# 4         0        0

# %%
test['Sex'] = test['Sex'].apply(lambda x: 1 if x == 'male' else 0)
test.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked Title  \
# 0          892       3    1  34.5      0      0   7.8292         1   Mr.
# 1          893       3    0  47.0      1      0   7.0000         2  Mrs.
# 2          894       2    1  62.0      0      0   9.6875         1   Mr.
# 3          895       3    1  27.0      0      0   8.6625         2   Mr.
# 4          896       3    0  22.0      1      1  12.2875         2  Mrs.
#
#    ageGroup  isAlone
# 0         0        1
# 1         0        0
# 2         0        1
# 3         0        1
# 4         0        0

# %%
encoder_title = preprocessing.LabelEncoder()
title = encoder_title.fit_transform(test['Title'])
encoder_title.classes_
# Out:
# array(['Master.', 'Miss.', 'Mr.', 'Mrs.', 'Other'], dtype=object)

# %%
test['Title'] = title
test.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  \
# 0          892       3    1  34.5      0      0   7.8292         1      2
# 1          893       3    0  47.0      1      0   7.0000         2      3
# 2          894       2    1  62.0      0      0   9.6875         1      2
# 3          895       3    1  27.0      0      0   8.6625         2      2
# 4          896       3    0  22.0      1      1  12.2875         2      3
#
#    ageGroup  isAlone
# 0         0        1
# 1         0        0
# 2         0        1
# 3         0        1
# 4         0        0

# %%
test['Fare'] = test_age_group['Fare'].fillna(0)

# %%
parameters = {'max_depth': np.arange(1, 10, 1), 
              'min_samples_split': np.arange(2, 10, 1), 
              'min_samples_leaf': np.arange(1, 10, 1)}

tree = DecisionTreeClassifier(random_state=0).fit(X_train, y_train)
clf = GridSearchCV(tree, parameters, cv=10,scoring='balanced_accuracy')

clf.fit(X_train, y_train)

print(clf.best_score_,clf.best_params_)
print("Accuracy:",metrics.accuracy_score(y_test, clf.predict(X_test)))
# Out:
# 0.8014176489973459 {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8100558659217877
# /home/vccolombo/Programing/titanic/.venv/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  \
# 0          892       3    1  34.5      0      0   7.8292         1      2
# 1          893       3    0  47.0      1      0   7.0000         2      3
# 2          894       2    1  62.0      0      0   9.6875         1      2
# 3          895       3    1  27.0      0      0   8.6625         2      2
# 4          896       3    0  22.0      1      1  12.2875         2      3
#
#    ageGroup  isAlone
# 0         0        1
# 1         0        0
# 2         0        1
# 3         0        1
# 4         0        0

# %%
result = pd.concat([test['PassengerId'], pd.DataFrame(clf.predict(test.drop(['PassengerId'],axis=1)))], axis=1)

# %%
result.head()
# Out:
#    PassengerId  0
# 0          892  0
# 1          893  0
# 2          894  0
# 3          895  0
# 4          896  0

# %%
result.to_csv('result.csv', index = None, header=True)
